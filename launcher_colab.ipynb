# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ls
# %cd gdrive/My Drive/wind_power_forecasting_challenge/wind-power-forecasting-challenge
#! git clone https://github.com/qcha41/wind-power-forecasting-challenge
! git pull
! python main.py
